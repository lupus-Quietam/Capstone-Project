# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2022-02-25 21:52:15--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  30.5MB/s    in 1.1s
#
# 2022-02-25 21:52:16 (30.5 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age asc
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np



Query= """
SELECT ConvertedComp
FROM master
"""

df_convertedcomp = pd.read_sql_query(Query, conn)


ax = df_convertedcomp['ConvertedComp'].plot(kind='hist', figsize=(8,6))
ax.set_xlabel('Concerted Compensation')
ax.set_ylabel('Amount')
ax.set_title('Histogram of CovertedComp')

plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

Query1= """
SELECT Age
FROM master
"""

df_age = pd.read_sql_query(Query1, conn)

plt.figure(figsize=(12,6))

ax1 = sns.boxplot(x=df_age['Age'], data=df_age )
ax1.set_xlabel('Ages')
ax1.set_title('Box Plot of Age')

plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here

Query2= """
SELECT Age, WorkWeekHrs
FROM master
"""

df_age_workweekhrs = pd.read_sql_query(Query2, conn)

plt.figure(figsize=(16,6))

ax3 = sns.scatterplot(x=df_age_workweekhrs['Age'], y=df_age_workweekhrs['WorkWeekHrs'], data=df_age_workweekhrs )
ax3.set(xlabel='Ages', ylabel='Work Week Hours')
ax3.set_title('Scatter Plot of Age against WorkWeekHrs')

plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here

Query3= """
SELECT Age, WorkWeekHrs, CodeRevHrs
FROM master
"""

df_age_workweekhrs_coderevhrs = pd.read_sql_query(Query3, conn)

plt.figure(figsize=(16,10))

ax3 = sns.scatterplot(x=df_age_workweekhrs_coderevhrs['WorkWeekHrs'], y=df_age_workweekhrs_coderevhrs['CodeRevHrs'], size=df_age_workweekhrs_coderevhrs['Age'],sizes=(30,1000),alpha=.5, data=df_age_workweekhrs_coderevhrs)
ax3.set(xlabel='Work Week Hours', ylabel='Code Rev Hours')
ax3.set_title('Bubble Plot of WorkWeekHrs against CodeRevHrs')

plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here

Query4 = """
SELECT DatabaseDesireNextYear, COUNT(*) as Total
FROM DatabaseDesireNextYear
group by DatabaseDesireNextYear
order by Total DESC
LIMIT 5
"""

df_DatabaseDesireNextYear = pd.read_sql_query(Query4, conn)

colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen']
explode_list = [0.08, 0.08, 0.08, 0, 0] # ratio for each continent with which to offset each wedge.

df_DatabaseDesireNextYear['Total'].plot(kind='pie',
                            figsize=(17, 8),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the distance of the text generated by autopct from the center of pie
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )
plt.title('Pie Chart of The Top 5 Databases Respondents Wish To Learn Next Year') 
plt.axis('equal') 

# add legend
plt.legend(labels=df_DatabaseDesireNextYear['DatabaseDesireNextYear'], loc='upper left') 

plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
#"""
#Query5 = """
#SELECT WorkWeekHrs, CodeRevHrs
#FROM master
#WHERE Age >= 30 AND Age <= 35
#group by Age
#order by Age
#"""

#df_WorkWeekHrs_CodeRevHrs = pd.read_sql_query(Query5, conn)

#ax4 = df_WorkWeekHrs_CodeRevHrs.plot(kind='area', alpha=0.35, figsize=(16, 6))

#ax4.set_title('Stacked Chart Of Median WorkWeekHrs And CodeRevHrs For The Age Group 30 To 35')
#ax4.set_ylabel('CodeRevHrs')
#ax4.set_xlabel('WorkWeekHrs')

#plt.show()

Query5 = """
SELECT Age,WorkWeekHrs,CodeRevHrs
FROM master
WHERE Age >= 30 AND Age <= 35
"""

df_WorkWeekHrs_CodeRevHrs = pd.read_sql_query(Query5, conn)
df_grouped=df_WorkWeekHrs_CodeRevHrs.groupby('Age').median()

ax4 = df_grouped.plot(kind='bar',stacked=True, alpha=0.35, figsize=(12, 6))

ax4.set_title('Stacked Chart Of Median WorkWeekHrs And CodeRevHrs For The Age Group 30 To 35')
ax4.set_ylabel('CodeRevHrs')
ax4.set_xlabel('WorkWeekHrs')

plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
Query6 = """
SELECT Age, ConvertedComp
FROM master
WHERE Age BETWEEN 45 AND 60
"""
df_Age_ConvertedComp = pd.read_sql_query(Query6,conn)
df_grouped1=df_Age_ConvertedComp.groupby('Age').median()

ax4 = df_grouped1.plot(figsize=(12, 6))

ax4.set_title('Stacked Chart Of Median WorkWeekHrs And CodeRevHrs For The Age Group 30 To 35')
ax4.set_ylabel('CodeRevHrs')
ax4.set_xlabel('WorkWeekHrs')

plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here

Query7 = """
SELECT MainBranch, COUNT(*) as Total
FROM master
group by MainBranch
"""
df_MainBranch = pd.read_sql_query(Query7,conn)

plt.figure(figsize=(10,4))

ax5 = sns.barplot(y= df_MainBranch['MainBranch'], x= df_MainBranch['Total'],data=df_MainBranch)
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
